# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import ssl

# Отключаем проверку SSL-сертификатов
ssl._create_default_https_context = ssl._create_unverified_context

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/твой айди/export?format=csv')
df.head()
# Out:
#    id  user_id                                       theme  \
# 0   4        2                                     SO GOOD
# 1   5      356  Unusable input in the middle of the screen
# 2   6      337                        Subscription renewed
# 3   7      337                        Subscription renewed
# 4   8      353                             Windows version
#
#                                              message          inserted_at  \
# 0                                      SUCH MUCH WOW  2023-09-18 13:51:23
# 1  Hi. It can be frustrating and unclear on how t...  2024-03-13 16:20:07
# 2  App is not registering the renewal, and not al...  2024-03-27 14:42:59
# 3  App is not registering the renewal, and not al...  2024-03-27 14:43:00
# 4  I can run several instances of Pismo at the sa...  2024-05-10 12:49:18
#
#             updated_at
# 0  2023-09-18 13:51:23
# 1  2024-03-13 16:20:07
# 2  2024-03-27 14:42:59
# 3  2024-03-27 14:43:00
# 4  2024-05-10 12:49:18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           202 non-null    int64
#  1   user_id      202 non-null    int64
#  2   theme        187 non-null    object
#  3   message      199 non-null    object
#  4   inserted_at  202 non-null    object
#  5   updated_at   202 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 9.6+ KB

# %%
df['user_id'].nunique()
# Out:
# 156

# %%
# Объединяем все сообщения в одну строку с разделителем
all_messages = "\n---\n".join(df["message"].dropna().astype(str))

# Выводим часть результата
print(all_messages[:1000])  # Показываем первые 1000 символов для проверки
# Out:
# SUCH MUCH WOW
# ---
# Hi. It can be frustrating and unclear on how to close a popup that covers your screen.
# ---
# App is not registering the renewal, and not allowing me to reset and login again
# ---
# App is not registering the renewal, and not allowing me to reset and login again
# ---
# I can run several instances of Pismo at the same time
# ---
# Test
# ---
# test2
# ---
# test3
# ---
# How do I remove this weird floating thing on my monitor? I have 3 screens connected, on my middle screen I have a PISMO widget on top of everything else. I want this gone ASAP, it is VERY annoying!
# ---
# I have tried Outlook and a few other programs, and Pismo always says
# It appears that there is no text provided for me to rewrite. Please provide the text you would like me to transform
# ---
# Is it possible to change to UK English
# ---
# I can't find the option to see how much credit I spent/is left, is that available?
# ---
# ...

# %%
file_path = "/Users/user/Pismo/Reports.txt"  # Указываем полный путь

# Записываем текст в файл (перезаписывает содержимое)
with open(file_path, "w", encoding="utf-8") as file:
    file.write(all_messages)

print(f"Файл успешно обновлен: {file_path}")
# Out:
# Файл успешно обновлен: /Users/user/Pismo/Reports.txt

# %% [markdown]
# Основные жалобы:
# Проблемы с обновлениями:
#
# Приложение требует обновления, но после рестарта ничего не меняется.
# Регулярные уведомления о необходимости обновления, которые невозможно отключить.
# Проблемы с пользовательским интерфейсом:
#
# Окно Pismo сужается после нескольких запусков и не сохраняет размер.
# Приложение открывается на другом экране при работе с несколькими мониторами.
# Виджет занимает слишком много места или не перемещается.
# Проблемы с масштабированием интерфейса (особенно на 4K мониторах).
# Проблемы с горячими клавишами:
#
# Глобальные сочетания клавиш конфликтуют с другими программами.
# Нет возможности изменить или отключить определенные сочетания.
# Проблемы с копированием и вставкой текста:
#
# Текст не заменяется, а дублируется или вставляется не туда.
# Приложение не копирует текст в буфер обмена.
# Переводы и языковые настройки:
#
# Некорректные переводы интерфейса (особенно в испанском, французском, немецком).
# Отсутствует поддержка традиционного китайского.
# Отсутствует опция смены языка интерфейса.
# Проблемы с отображением арабского текста (LTR вместо RTL).
# Производительность и стабильность:
#
# Приложение зависает, особенно при длинных запросах.
# Некоторые функции перестают работать после нескольких использований.
# Ошибки при использовании с VPN.
# Функциональные ограничения:
#
# Нет возможности изменить порядок сохраненных команд.
# Нет истории запросов.
# Нет функции синхронизации настроек между устройствами.
# Нет возможности использовать собственный OpenAI API ключ.
# Нет OCR для работы с изображениями.
# Лицензирование и учетная запись:
#
# Пользователи не могут активировать купленные лицензии (особенно через AppSumo).
# Учетная запись не обновляется после покупки пожизненной лицензии.
# 🟢 Основные пожелания:
# Кастомизация интерфейса:
#
# Возможность изменить цветовую схему (темный режим).
# Возможность менять размер шрифтов.
# Гибкость настроек:
#
# Возможность переопределять и отключать сочетания клавиш.
# Возможность закреплять пользовательские команды вверху списка.
# Дополнительные функции:
#
# Поддержка синхронизации данных через облако.
# Возможность задавать прокси-сервер.
# Мобильное приложение.
# Инструкция и справка:
#
# Добавление встроенных руководств по использованию.

# %%
df_deactivated_licenses_revoke = pd.read_csv('https://docs.google.com/spreadsheets/d/твой айди/export?format=csv')
df_deactivated_licenses_revoke.head()
# Out:
#                             license_key                     purchase_date  \
# 0  c1d9fe1c-18a4-41db-a6f0-e82fc2f6cdbb  2024-10-05 03:37:52.358821+00:00
# 1  142929c2-c11d-484b-859c-1c977bfdbe56  2024-10-05 04:51:17.872774+00:00
# 2  69ba430e-ba76-40e1-a136-646992afb44d  2024-10-09 04:01:54.343270+00:00
# 3  6e331ec7-edd9-435e-bbfe-8d2eab572faf  2024-10-05 04:51:17.894860+00:00
# 4  b4927853-5c39-4917-8616-ec8d44c17ed7  2024-10-06 04:37:22.958954+00:00
#
#                         refund_date  \
# 0  2024-11-06 08:49:49.715708+00:00
# 1  2024-11-20 13:26:33.445351+00:00
# 2  2024-11-04 15:25:59.042299+00:00
# 3  2024-11-20 13:25:59.487680+00:00
# 4  2024-10-06 13:23:44.540606+00:00
#
#                                        reason  \
# 0                                       Other
# 1                                       Other
# 2  Product was difficult to use or understand
# 3                                       Other
# 4                            No longer needed
#
# ...

# %%
# Объединяем все сообщения в одну строку с разделителем
all_messages = "\n---\n".join(df_deactivated_licenses_revoke["feedback"].dropna().astype(str))

# Выводим часть результата
print(all_messages[:1000])  # Показываем первые 1000 символов для проверки
# Out:
# Simple reason
# It just never worked on my Mac.
# I did emailed pismo but never got any respond  So
#  I gave up trying
# ---
# I think this is a great product. I would love to be able to use voice dictation, for instance. For now, AutoHotkey and ChatGPT have given me the AI auto-correction I need, with a 0.01 daily cost.
# ---
# Was not alle to use properly
# ---
# I think this is a great product. I would love to be able to use voice dictation, for instance. For now, AutoHotkey and ChatGPT have given me the AI auto-correction I need, with a 0.01 daily cost.
# ---
# purchased twice
# ---
# no reason provided
# ---
# Great software, however the UI was not so comfortable for me.
# ---
# I think this is a great product. I would love to be able to use voice dictation, for instance. For now, AutoHotkey and ChatGPT have given me the AI auto-correction I need, with a 0.01 daily cost.
#
# ---
# Just tested the product.
# ---
# ...

# %%
file_path = "/Users/user/Pismo/feedback.txt"  # Указываем полный путь

# Записываем текст в файл (перезаписывает содержимое)
with open(file_path, "w", encoding="utf-8") as file:
    file.write(all_messages)

print(f"Файл успешно обновлен: {file_path}")
# Out:
# Файл успешно обновлен: /Users/user/Pismo/feedback.txt

# %% [markdown]
# Обобщенный отчет по жалобам и пожеланиям пользователей Pismo
# 🔴 Основные проблемы
# 1. Проблемы с обновлениями
# Приложение требует обновления, но после рестарта ничего не меняется.
# Регулярные уведомления о необходимости обновления, которые невозможно отключить.
# После обновления некоторые функции перестают работать.
# 2. Проблемы с пользовательским интерфейсом
# Окно Pismo сужается после нескольких запусков и не сохраняет размер.
# Приложение открывается на другом экране при работе с несколькими мониторами.
# Виджет занимает слишком много места или не перемещается.
# Проблемы с масштабированием интерфейса, особенно на 4K мониторах.
# 3. Проблемы с горячими клавишами
# Глобальные сочетания клавиш конфликтуют с другими программами.
# Нет возможности изменить или отключить определенные сочетания.
# Некоторые комбинации перестают работать после обновления.
# 4. Проблемы с копированием и вставкой текста
# Текст не заменяется, а дублируется или вставляется не туда.
# Приложение не копирует текст в буфер обмена.
# Вставка текста происходит с задержкой.
# 5. Проблемы с переводами и языковыми настройками
# Некорректные переводы интерфейса (особенно в испанском, французском, немецком).
# Отсутствует поддержка традиционного китайского.
# Нет опции смены языка интерфейса.
# Проблемы с отображением арабского текста (LTR вместо RTL).
# 6. Производительность и стабильность
# Приложение зависает, особенно при длинных запросах.
# Некоторые функции перестают работать после нескольких использований.
# Ошибки при использовании с VPN.
# Проблемы с загрузкой данных после обновлений.
# 7. Функциональные ограничения
# Нет возможности изменить порядок сохраненных команд.
# Нет истории запросов.
# Нет функции синхронизации настроек между устройствами.
# Нет возможности использовать собственный OpenAI API-ключ.
# Отсутствует OCR для работы с изображениями.
# 8. Лицензирование и учетная запись
# Пользователи не могут активировать купленные лицензии (особенно через AppSumo).
# Учетная запись не обновляется после покупки пожизненной лицензии.
# Проблемы с привязкой аккаунта к устройству.
#
# 🟢 Основные пожелания пользователей
# 1. Кастомизация интерфейса
# Возможность изменить цветовую схему (темный режим).
# Возможность менять размер шрифтов.
# Опция компактного вида интерфейса.
# 2. Гибкость настроек
# Возможность переопределять и отключать сочетания клавиш.
# Возможность закреплять пользовательские команды вверху списка.
# Возможность выбора режима отображения интерфейса (классический/новый).
# 3. Дополнительные функции
# Поддержка синхронизации данных через облако.
# Возможность задавать прокси-сервер.
# Мобильное приложение.
# Интеграция с другими инструментами (Notion, Trello, Slack).
# Расширенная система аналитики для анализа использованных запросов.
# 4. Инструкция и справка
# Добавление встроенных руководств по использованию.
# Более детальное описание новых функций после обновлений.
# Чат-поддержка прямо в приложении.
#
# 📊 Итоговый вывод
# Основные проблемы связаны с производительностью, стабильностью приложения, интерфейсом и функциональными ограничениями.
# Жалобы на лицензирование и учетную запись повторяются, особенно среди пользователей AppSumo.
# Пользователи хотят больше кастомизации и гибкости в настройках.
# Большой запрос на новые функции, такие как мобильное приложение и интеграции.
# Необходимо улучшить документацию и поддержку пользователей.
# Этот отчет объединяет жалобы из обоих файлов и показывает повторяющиеся проблемы. Если нужно выделить что-то конкретное или добавить детали, сообщите.
